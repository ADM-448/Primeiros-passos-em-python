# %%
#EX 16: CRIE UM PROGRAMA QUE QUE LEIA UM NÚMERO REAL QUALQUER PELO TECLADO E MOSTRE SUA PORÇÃO INTEIRA
import math
num = float(input('Digite um valor: '))
print('O valor digitado foi {} e sua porção inteira é {}'.format(num, math.trunc(num)))
# ou
from math import trunc
num = float(input('Digite um valor: '))
print('O valor digitado foi {} e sua porção inteira é {}'.format(num, trunc(num)))
# ou
num = float(input('Digite um valor: '))
print('O valor digitado foi {} e sua porção inteira é {}'.format(num, int(num)))
#EX 17: FAÇA UM PROGRAMA QUE LEIA UM COMPRIMENTO DO CATETO OPOSTO E ADJACENTE E MOSTRE SUA HIPOTENUSA
a = float(input('Digite um valor para o cateto oposto: '))
b = float(input('Digite um valor para o cateto adjacente: '))
# hip = a^2=b^2+c^2 -> raiz de (b^2 + c^2)
c = (a**2 + b**2)**(1/2)
print('O cateto oposto é {}, o cateto adjacente é {} e sua hipotenusa é {}'.format(a, b, c))
#ou
import math
e = float(input('Digite um valor para o cateto oposto: '))
f= float(input('Digite um valor para o cateto adjacente: '))
g = math.hypot(e, f)
print('A hipotenusas dos catetos é {:.3f}'.format(g))
# EX 18: FAÇA UM PROGRAMA QUE LEIA UM ANGULO E MOSTRE O COSSENO, SENO E TANGENTE DO MESMO ANGULO
import math
an = float(input('Digite um valor para um Ângulo qualquer: '))
x = math.cos(math.radians(an))
y = math.sin(math.radians(an))
z = math.tan(math.radians(an))
print('O cosseno do angulo {} é {:.3f} o seno é {:.3f} e a tangente é {:.3f}'.format(an, x, y, z))
#ou
from math import radians, sin, cos, tan
An = float(input('Digite um valor para Calcular o ângulo:'))
seno = sin(radians(An))
cosseno = cos(radians(An))
tangente = tan(radians(An))
print('O SENO do Ângulo {} é {:.3f}'.format(An, seno))
print ('O COSSENO do Ângulo {} é {:.3f}'.format(An, cosseno))
print ('A TANGENTE do Ângulo {} é {:.3f}'.format(An, tangente))
#EX 19: FAÇA UM PROGRAMA QUE SORTEIA 4 NOMES ALEATÓRIOS
import random
pr = str(input('Primeiro Aluno: '))
se = str(input('Segundo Aluno: '))
tr = str(input('Terceiro Aluno: '))
qu = str(input('Quarto aluno: '))
lista = [pr, se, tr, qu]
sorteio = random.choice(lista)
print('O nome sorteado foi {}, Parabéns '.format(sorteio))
# ou
from random import choice
Pr = str(input('Primeiro Nome: '))
Se = str(input("Segundo Nome: "))
Tr = str(input('Terceiro Nome: '))
Qu = str(input('Quarto Nome: '))
Lista = [Pr, Se, Tr, Qu]
Escolhido = choice(Lista)
print('O escolhido foi {}'.format(Escolhido))

# EX 20: FAÇA UM PROGRAMA QUE SORTEIA UMA ORDEM ALEATÓRIA DOS NOMES DO EX ANTERIOR
import random
pr = str(input('Primeiro Aluno: '))
se = str(input('Segundo Aluno: '))
tr = str(input('Terceiro Aluno: '))
qu = str(input('Quarto aluno: '))
lista = [pr, se, tr, qu]
random.shuffle(lista)
print('A ordem será {}'.format(lista))
# ou
from random import shuffle
Pr = str(input('Primeiro Nome: '))
Se = str(input("Segundo Nome: "))
Tr = str(input('Terceiro Nome: '))
Qu = str(input('Quarto Nome: '))
Lista = [Pr, Se, Tr, Qu]
shuffle(Lista)
print('A ordem será {}'.format(Lista))
# EX 21: FAÇA UM PROGRAMA QUE LEIA E REPRODUZA UM ARQUIVO MP3
#https://drive.google.com/drive/folders/1YFYihuFo_l_S2cKMApSrbsg_4LAGJ2Y0
from pyautogui import press, click, write
import time
press('win')
time.sleep(5)
write("Gogle Chrome")
press('enter')
time.sleep(5)
write('https://drive.google.com/drive/folders/1YFYihuFo_l_S2cKMApSrbsg_4LAGJ2Y0')
press('enter')
time.sleep(5)
click(827,422)
click(827,422)
